# %% [markdown]
# <a href="https://colab.research.google.com/github/geovannathereza/curso-de-machine-learning/blob/main/aula8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#o que já sabemos?
empresas = ['Apple', 'Google', 'Amazon',
            'Microsoft', 'Tencent',
            "McDonald's", 'Visa',
            'Facebook', 'Alibaba',
            'Louis Vuitton']

# %%
bilhoes = [947.062, 819.573, 705.646,
           611.460, 214.023, 196.526,
           191.032, 186.421, 169.966,
           124.273 ]

# %%
# já é possível plotar, só com as variáveis
plt.plot(empresas, bilhoes)

# %%
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo')
# Out:
# Text(0.5, 1.0, 'Empresas mais ricas do mundo')

# %%
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo')
plt.xlabel('empresas')
plt.ylabel('bilhões')
# Out:
# Text(0, 0.5, 'bilhões')

# %%
plt.rcParams['figure.figsize'] = (15, 8)
plt.plot(empresas, bilhoes)
plt.title('Empresas mais ricas do mundo')
plt.xlabel('empresas')
plt.ylabel('bilhões')
# Out:
# Text(0, 0.5, 'bilhões')

# %%
plt.plot(empresas, bilhoes)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.title('Empresas mais ricas do mundo', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Empresas mais ricas do mundo')

# %%
plt.plot(empresas, bilhoes, color = 'green')
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)

# %%
plt.plot(empresas, bilhoes, color = 'green', lw=3)
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)

# %%
plt.plot(empresas, bilhoes, color = 'green', lw=2, marker = 'o')
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)

# %%
plt.plot(empresas, bilhoes, color = 'green', lw=2, marker = 'o')
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.grid(True)

# %%
plt.bar(empresas, bilhoes, color = 'green')
plt.xlabel('Empresas', fontsize=20)
plt.ylabel('Bilhões', fontsize=20)
plt.title('Empresas mais ricas do mundo', fontsize=25)
plt.legend(['Bilhões de dólares'], loc = 'center right', fontsize=15)
plt.grid(True)

# %%
plt.bar(empresas, bilhoes)
# Out:
# <BarContainer object of 10 artists>

# %%
cores = ['black', 'dimgray', 'dimgray', 'gray', 'grey', 'darkgray', 'darkgrey', 'silver', 'lightgray', 'lightgrey']

# %%
plt.bar(empresas, bilhoes, color = cores, edgecolor='black')
plt.title('Empresas mais ricas do mundo', fontsize = 25)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.xlabel('Empresas', fontsize=20)
plt.grid(True)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 8)
plt.bar(empresas, bilhoes, color = cores, edgecolor= 'black')
plt.title('Empresas mais ricas do mundo', fontsize = 25)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.xlabel('Empresas', fontsize=20)
plt.show()

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 8)
plt.barh(empresas, bilhoes, color = cores, edgecolor= 'black')
plt.title('Empresas mais ricas do mundo', fontsize = 25)
plt.ylabel('Empresas', fontsize=20)
plt.xlabel('Bilhões de dólares', fontsize=20)
plt.show()

# %%
plt.style.use('seaborn-white')
plt.scatter(empresas, bilhoes, color = cores, edgecolor = 'black')
plt.title('Empresas mais ricas do mundo', fontsize = 25)
plt.ylabel('Bilhões de dólares', fontsize=20)
plt.xlabel('Empresas', fontsize=20)
plt.grid(True)
plt.show()
