# %% [markdown]
# <a href="https://colab.research.google.com/github/geovannathereza/curso-de-machine-learning/blob/main/Atividade_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Obtendo os dados:
# Ao rodarmos a célula abaixo vamos obter os dados diretamente do site:
#
# http://dados.recife.pe.gov.br/tl/dataset/relacao-de-pessoas-vacinadas-covid-19/resource/966e9c4c-df45-40d7-9c58-2f13c61a6d28

# %%
df1 = pd.read_csv('http://dados.recife.pe.gov.br/dataset/2b5ee58d-9535-4d80-ab32-f63fd475346e/resource/93f4e8c2-430f-4142-86b3-96dab4905b4e/download/casosgravescovid.csv', sep=";")

# %% [markdown]
# Utilize os comandos aprendidos em aula para os dados carregados, começando, preferencialmente, por:
# - head()
# - head(1-2)
# - tail()
# - info()
# - describe()
# - seguindo com outros aprendidos para manipulação de tratamento dos dados.

# %%
df1.shape
# Out:
# (36435, 18)

# %%
df1.head()
# Out:
#   data_notificacao       sexo    raca etnia idade municipio_residencia  \
# 0       2020-05-30  Masculino  Branca   NaN    53               Recife
# 1       2020-06-02   Feminino   Parda   NaN     0               Recife
# 2       2020-06-02   Feminino   Parda   NaN    86               Recife
# 3       2020-06-01  Masculino  Branca   NaN    66               Recife
# 4       2020-06-02  Masculino   Preta   NaN    68               Recife
#
#                  bairro distrito_sanitario data_inicio_sintomas  \
# 0            SAN MARTIN                  V           2020-05-25
# 1  ALTO SANTA TEREZINHA                 II           2020-05-30
# 2            ESPINHEIRO                III           2020-06-01
# 3            CASA FORTE                III           2020-05-25
# 4        ILHA DO RETIRO                 IV           2020-05-30
#
#                                             sintomas outros_sintomas  \
# 0  Febre, Tosse, Mialgia, Alteração/perda de olfa...             NaN
# 1          Febre, Tosse, Dispneia, Saturação O2 < 95             NaN
# 2                        Dispneia, Saturação O2 < 95             NaN
# 3                                                NaN             NaN
# 4                 Tosse, Dispneia, Saturação O2 < 95             NaN
#
#   doencas_preexistentes outras_doencas_preexistentes  profissional_saude  \
# 0                   NaN                           NaN                NaN
# 1                   NaN                           NaN                NaN
# 2                   NaN                           NaN                NaN
# 3                   NaN                           NaN                NaN
# 4                   NaN                           NaN                NaN
#
#   categoria_profissional classificacao_final                       evolucao  \
# 0                    NaN          DESCARTADO          ISOLAMENTO DOMICILIAR
# 1                    NaN        INCONCLUSIVO          ISOLAMENTO DOMICILIAR
# 2                    NaN          DESCARTADO  INTERNADO LEITO DE ISOLAMENTO
# 3                    NaN          CONFIRMADO                     RECUPERADO
# 4                    NaN          DESCARTADO  INTERNADO LEITO DE ISOLAMENTO
#
#   data_obito
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df1.tail()
# Out:
#       data_notificacao       sexo      raca etnia idade municipio_residencia  \
# 36430       2022-06-08  Masculino  Ignorado   NaN    77               Recife
# 36431       2022-06-09  Masculino     Parda   NaN    74               Recife
# 36432       2022-06-10  Masculino     Parda   NaN    74               Recife
# 36433       2022-06-12   Feminino   Amarela   NaN    73               Recife
# 36434       2022-06-12   Feminino     Parda   NaN    66               Recife
#
#                    bairro distrito_sanitario data_inicio_sintomas  \
# 36430  BREJO DA GUABIRABA                VII           2022-06-06
# 36431     NOVA DESCOBERTA                VII           2022-06-06
# 36432            BEBERIBE                 II           2022-06-03
# 36433     ENGENHO DO MEIO                 IV           2022-06-11
# 36434          BOA VIAGEM                 VI           2022-06-07
#
#                                                 sintomas outros_sintomas  \
# 36430                                           Dispneia             NaN
# 36431  Tosse, Cansaço/fadiga, Desconforto respiratóri...             NaN
# 36432                             Febre, Tosse, Dispneia             NaN
# 36433  Dispneia, Desconforto respiratório / aperto to...             NaN
# 36434  Tosse, Dispneia, Desconforto respiratório / ap...             RNC
#
#                            doencas_preexistentes  \
# 36430                                        NaN
# 36431                                        NaN
# 36432                                   Diabetes
# 36433  Doenças Cardíacas ou Vasculares, Diabetes
# 36434                                        NaN
#
#       outras_doencas_preexistentes  profissional_saude categoria_profissional  \
# 36430                           HAS                NÃO                    NaN
# 36431                           NaN                NÃO                    NaN
# 36432                           NaN                NÃO                    NaN
# 36433                           AVC                NÃO                    NaN
# 36434                          AVCH                NÃO                    NaN
#
#       classificacao_final                       evolucao data_obito
# 36430          EM ANÁLISE                  INTERNADO UTI        NaN
# 36431          EM ANÁLISE  INTERNADO LEITO DE ISOLAMENTO        NaN
# 36432          EM ANÁLISE  INTERNADO LEITO DE ISOLAMENTO        NaN
# 36433          EM ANÁLISE                  INTERNADO UTI        NaN
# 36434          EM ANÁLISE                  INTERNADO UTI        NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36435 entries, 0 to 36434
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   data_notificacao               36435 non-null  object
#  1   sexo                           36435 non-null  object
#  2   raca                           30106 non-null  object
#  3   etnia                          4 non-null      object
#  4   idade                          36435 non-null  object
#  5   municipio_residencia           36435 non-null  object
#  6   bairro                         36435 non-null  object
#  7   distrito_sanitario             36435 non-null  object
#  8   data_inicio_sintomas           36435 non-null  object
#  9   sintomas                       34477 non-null  object
#  10  outros_sintomas                5974 non-null   object
#  11  doencas_preexistentes          13698 non-null  object
#  12  outras_doencas_preexistentes   7807 non-null   object
#  13  profissional_saude             27338 non-null  object
#  14  categoria_profissional         2914 non-null   object
#  15  classificacao_final            36435 non-null  object
#  16  evolucao                       35458 non-null  object
#  17  data_obito                     9344 non-null   object
# dtypes: object(18)
# memory usage: 5.0+ MB

# %%
df1.describe()
# Out:
#        data_notificacao      sexo   raca     etnia  idade  \
# count             36435     36435  30106         4  36435
# unique              836         3      6         1    127
# top          2020-04-23  Feminino  Parda  Ignorado     57
# freq                464     18643  15040         4    646
#
#        municipio_residencia      bairro distrito_sanitario  \
# count                 36435       36435              36435
# unique                    3         106                 10
# top                  Recife  BOA VIAGEM                 IV
# freq                  36433        2972               6392
#
#        data_inicio_sintomas                                   sintomas  \
# count                 36435                                      34477
# unique                  850                                       3440
# top              2020-04-20  Febre, Tosse, Dispneia, Saturação O2 < 95
# freq                    359                                       2535
#
#        outros_sintomas            doencas_preexistentes  \
# count             5974                            13698
# unique            2370                              244
# top            ASTENIA  Doenças Cardíacas ou Vasculares
# freq               946                             3827
#
#        outras_doencas_preexistentes  profissional_saude  \
# count                           7807              27338
# unique                          3344                  2
# top                              HAS                NÃO
# freq                            1493              24424
#
#                         categoria_profissional classificacao_final  \
# count                                     2914               36435
# unique                                      23                   4
# top     Outro profissional de serviço de saúde          CONFIRMADO
# freq                                      1900               17816
#
#           evolucao  data_obito
# count        35458        9344
# unique           5         785
# top     RECUPERADO  2020-05-09
# freq         18931          72

# %%
df1.isnull()
# Out:
#        data_notificacao   sexo   raca  etnia  idade  municipio_residencia  \
# 0                 False  False  False   True  False                 False
# 1                 False  False  False   True  False                 False
# 2                 False  False  False   True  False                 False
# 3                 False  False  False   True  False                 False
# 4                 False  False  False   True  False                 False
# ...                 ...    ...    ...    ...    ...                   ...
# 36430             False  False  False   True  False                 False
# 36431             False  False  False   True  False                 False
# 36432             False  False  False   True  False                 False
# 36433             False  False  False   True  False                 False
# 36434             False  False  False   True  False                 False
#
#        bairro  distrito_sanitario  data_inicio_sintomas  sintomas  \
# 0       False               False                 False     False
# 1       False               False                 False     False
# 2       False               False                 False     False
# 3       False               False                 False      True
# 4       False               False                 False     False
# ...       ...                 ...                   ...       ...
# 36430   False               False                 False     False
# 36431   False               False                 False     False
# 36432   False               False                 False     False
# 36433   False               False                 False     False
# 36434   False               False                 False     False
#
#        outros_sintomas  doencas_preexistentes  outras_doencas_preexistentes   \
# 0                 True                   True                           True
# 1                 True                   True                           True
# 2                 True                   True                           True
# 3                 True                   True                           True
# 4                 True                   True                           True
# ...                ...                    ...                            ...
# 36430             True                   True                          False
# 36431             True                   True                           True
# 36432             True                  False                           True
# 36433             True                  False                          False
# 36434            False                   True                          False
#
#        profissional_saude  categoria_profissional  classificacao_final  \
# 0                    True                    True                False
# 1                    True                    True                False
# 2                    True                    True                False
# 3                    True                    True                False
# 4                    True                    True                False
# ...                   ...                     ...                  ...
# 36430               False                    True                False
# 36431               False                    True                False
# 36432               False                    True                False
# 36433               False                    True                False
# 36434               False                    True                False
#
#        evolucao  data_obito
# 0         False        True
# 1         False        True
# 2         False        True
# 3         False        True
# 4         False        True
# ...         ...         ...
# 36430     False        True
# 36431     False        True
# 36432     False        True
# 36433     False        True
# 36434     False        True
#
# [36435 rows x 18 columns]

# %%
df2 = df1.drop(columns= ['etnia', 'data_notificacao', 'idade', 'sexo', 'data_inicio_sintomas', 'profissional_saude', 'categoria_profissional'])
df2
# Out:
#            raca municipio_residencia                bairro distrito_sanitario  \
# 0        Branca               Recife            SAN MARTIN                  V
# 1         Parda               Recife  ALTO SANTA TEREZINHA                 II
# 2         Parda               Recife            ESPINHEIRO                III
# 3        Branca               Recife            CASA FORTE                III
# 4         Preta               Recife        ILHA DO RETIRO                 IV
# ...         ...                  ...                   ...                ...
# 36430  Ignorado               Recife    BREJO DA GUABIRABA                VII
# 36431     Parda               Recife       NOVA DESCOBERTA                VII
# 36432     Parda               Recife              BEBERIBE                 II
# 36433   Amarela               Recife       ENGENHO DO MEIO                 IV
# 36434     Parda               Recife            BOA VIAGEM                 VI
#
#                                                 sintomas outros_sintomas  \
# 0      Febre, Tosse, Mialgia, Alteração/perda de olfa...             NaN
# 1              Febre, Tosse, Dispneia, Saturação O2 < 95             NaN
# 2                            Dispneia, Saturação O2 < 95             NaN
# 3                                                    NaN             NaN
# 4                     Tosse, Dispneia, Saturação O2 < 95             NaN
# ...                                                  ...             ...
# 36430                                           Dispneia             NaN
# 36431  Tosse, Cansaço/fadiga, Desconforto respiratóri...             NaN
# 36432                             Febre, Tosse, Dispneia             NaN
# 36433  Dispneia, Desconforto respiratório / aperto to...             NaN
# 36434  Tosse, Dispneia, Desconforto respiratório / ap...             RNC
#
#                            doencas_preexistentes  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 36430                                        NaN
# 36431                                        NaN
# 36432                                   Diabetes
# 36433  Doenças Cardíacas ou Vasculares, Diabetes
# 36434                                        NaN
#
#       outras_doencas_preexistentes  classificacao_final  \
# 0                               NaN          DESCARTADO
# 1                               NaN        INCONCLUSIVO
# 2                               NaN          DESCARTADO
# 3                               NaN          CONFIRMADO
# 4                               NaN          DESCARTADO
# ...                             ...                 ...
# 36430                           HAS          EM ANÁLISE
# 36431                           NaN          EM ANÁLISE
# 36432                           NaN          EM ANÁLISE
# 36433                           AVC          EM ANÁLISE
# 36434                          AVCH          EM ANÁLISE
#
#                             evolucao data_obito
# 0              ISOLAMENTO DOMICILIAR        NaN
# 1              ISOLAMENTO DOMICILIAR        NaN
# 2      INTERNADO LEITO DE ISOLAMENTO        NaN
# 3                         RECUPERADO        NaN
# 4      INTERNADO LEITO DE ISOLAMENTO        NaN
# ...                              ...        ...
# 36430                  INTERNADO UTI        NaN
# 36431  INTERNADO LEITO DE ISOLAMENTO        NaN
# 36432  INTERNADO LEITO DE ISOLAMENTO        NaN
# 36433                  INTERNADO UTI        NaN
# 36434                  INTERNADO UTI        NaN
#
# [36435 rows x 11 columns]

# %%
df2.isnull().sum()
# Out:
# raca                              6329
# municipio_residencia                 0
# bairro                               0
# distrito_sanitario                   0
# sintomas                          1958
# outros_sintomas                  30461
# doencas_preexistentes            22737
# outras_doencas_preexistentes     28628
# classificacao_final                  0
# evolucao                           977
# data_obito                       27091
# dtype: int64

# %%
df3 = df2.drop(columns=['outros_sintomas', 'raca', 'doencas_preexistentes', 'data_obito'])
df3
# Out:
#       municipio_residencia                bairro distrito_sanitario  \
# 0                   Recife            SAN MARTIN                  V
# 1                   Recife  ALTO SANTA TEREZINHA                 II
# 2                   Recife            ESPINHEIRO                III
# 3                   Recife            CASA FORTE                III
# 4                   Recife        ILHA DO RETIRO                 IV
# ...                    ...                   ...                ...
# 36430               Recife    BREJO DA GUABIRABA                VII
# 36431               Recife       NOVA DESCOBERTA                VII
# 36432               Recife              BEBERIBE                 II
# 36433               Recife       ENGENHO DO MEIO                 IV
# 36434               Recife            BOA VIAGEM                 VI
#
#                                                 sintomas  \
# 0      Febre, Tosse, Mialgia, Alteração/perda de olfa...
# 1              Febre, Tosse, Dispneia, Saturação O2 < 95
# 2                            Dispneia, Saturação O2 < 95
# 3                                                    NaN
# 4                     Tosse, Dispneia, Saturação O2 < 95
# ...                                                  ...
# 36430                                           Dispneia
# 36431  Tosse, Cansaço/fadiga, Desconforto respiratóri...
# 36432                             Febre, Tosse, Dispneia
# 36433  Dispneia, Desconforto respiratório / aperto to...
# 36434  Tosse, Dispneia, Desconforto respiratório / ap...
#
#       outras_doencas_preexistentes  classificacao_final  \
# 0                               NaN          DESCARTADO
# 1                               NaN        INCONCLUSIVO
# 2                               NaN          DESCARTADO
# 3                               NaN          CONFIRMADO
# 4                               NaN          DESCARTADO
# ...                             ...                 ...
# 36430                           HAS          EM ANÁLISE
# 36431                           NaN          EM ANÁLISE
# 36432                           NaN          EM ANÁLISE
# 36433                           AVC          EM ANÁLISE
# 36434                          AVCH          EM ANÁLISE
#
#                             evolucao
# 0              ISOLAMENTO DOMICILIAR
# 1              ISOLAMENTO DOMICILIAR
# 2      INTERNADO LEITO DE ISOLAMENTO
# 3                         RECUPERADO
# 4      INTERNADO LEITO DE ISOLAMENTO
# ...                              ...
# 36430                  INTERNADO UTI
# 36431  INTERNADO LEITO DE ISOLAMENTO
# 36432  INTERNADO LEITO DE ISOLAMENTO
# 36433                  INTERNADO UTI
# 36434                  INTERNADO UTI
#
# [36435 rows x 7 columns]

# %%
df3.distrito_sanitario.unique()
# Out:
# array(['V', 'II', 'III', 'IV', 'VII', 'I', 'VIII', 'VI', 'IGN', 'v'],
#       dtype=object)

# %%
df3.evolucao.unique()
# Out:
# array(['ISOLAMENTO DOMICILIAR', 'INTERNADO LEITO DE ISOLAMENTO',
#        'RECUPERADO', 'ÓBITO', nan, 'INTERNADO UTI'], dtype=object)

# %%
df4 = df3.dropna()
df4
# Out:
#       municipio_residencia              bairro distrito_sanitario  \
# 13                  Recife       LINHA DO TIRO                 II
# 74                  Recife           BOA VISTA                  I
# 130                 Recife             TEJIPIO                  V
# 147                 Recife              VARZEA                 IV
# 184                 Recife          SAN MARTIN                  V
# ...                    ...                 ...                ...
# 36418               Recife               TORRE                 IV
# 36425               Recife           AGUA FRIA                 II
# 36430               Recife  BREJO DA GUABIRABA                VII
# 36433               Recife     ENGENHO DO MEIO                 IV
# 36434               Recife          BOA VIAGEM                 VI
#
#                                                 sintomas  \
# 13                                Febre, Tosse, Dispneia
# 74                                     Saturação O2 < 95
# 130    Tosse, Dispneia, Desconforto respiratório / ap...
# 147                                         Febre, Tosse
# 184    Dispneia, Desconforto respiratório / aperto to...
# ...                                                  ...
# 36418                   Tosse, Dispneia, Dor de Garganta
# 36425                                   Vômito, Diarreia
# 36430                                           Dispneia
# 36433  Dispneia, Desconforto respiratório / aperto to...
# 36434  Tosse, Dispneia, Desconforto respiratório / ap...
#
#       outras_doencas_preexistentes  classificacao_final  \
# 13               DOENCA NEUROLOGICA          DESCARTADO
# 74                       NEOPLASIAS          CONFIRMADO
# 130                       ALZHEIMER          DESCARTADO
# 147                      HAS E AVC?          CONFIRMADO
# 184                        ETILISTA          DESCARTADO
# ...                             ...                 ...
# 36418                           B24          DESCARTADO
# 36425                     tabagista          EM ANÁLISE
# 36430                           HAS          EM ANÁLISE
# 36433                           AVC          EM ANÁLISE
# 36434                          AVCH          EM ANÁLISE
#
#                             evolucao
# 13     INTERNADO LEITO DE ISOLAMENTO
# 74                        RECUPERADO
# 130                            ÓBITO
# 147                       RECUPERADO
# 184                            ÓBITO
# ...                              ...
# 36418  INTERNADO LEITO DE ISOLAMENTO
# 36425                          ÓBITO
# 36430                  INTERNADO UTI
# 36433                  INTERNADO UTI
# 36434                  INTERNADO UTI
#
# [7463 rows x 7 columns]

# %%
df3.evolucao
# Out:
# 0                ISOLAMENTO DOMICILIAR
# 1                ISOLAMENTO DOMICILIAR
# 2        INTERNADO LEITO DE ISOLAMENTO
# 3                           RECUPERADO
# 4        INTERNADO LEITO DE ISOLAMENTO
#                      ...
# 36430                    INTERNADO UTI
# 36431    INTERNADO LEITO DE ISOLAMENTO
# 36432    INTERNADO LEITO DE ISOLAMENTO
# 36433                    INTERNADO UTI
# 36434                    INTERNADO UTI
# Name: evolucao, Length: 36435, dtype: object

# %%
df3.distrito_sanitario
# Out:
# 0          V
# 1         II
# 2        III
# 3        III
# 4         IV
#         ...
# 36430    VII
# 36431    VII
# 36432     II
# 36433     IV
# 36434     VI
# Name: distrito_sanitario, Length: 36435, dtype: object
